# %%
import pdb
import json
import folium
import warnings
import numpy as np
import pandas as pd
import geopandas as gpd

warnings.filterwarnings("ignore")

# %% [markdown]
# Zillow Home Value Index (ZHVI): A smoothed, seasonally adjusted measure of the median estimated home value across a given region and housing type.
#
# https://www.zillow.com/research/data/

# %%
geo_df = gpd.read_file("data/dc_zip_geo.json")
geo_df.rename(columns={"ZCTA5CE10": "zipcode"}, inplace=True)
geo_df.zipcode.astype(str)
geo_df = geo_df[["zipcode", 'geometry']]
geo_df.head()
# Out:
#   zipcode                                           geometry
# 0   20024  (POLYGON ((-77.064251 38.888956, -77.064311 38...
# 1   20004  (POLYGON ((-77.031963 38.897349, -77.031955 38...
# 2   20566  POLYGON ((-77.05487100000001 38.897347, -77.05...
# 3   20535  POLYGON ((-77.02397499999999 38.893877, -77.02...
# 4   20551  POLYGON ((-77.044938 38.892101, -77.0466760000...

# %%
with open("data/dc_zip_geo.json") as jsonFile:
    geojson = json.load(jsonFile)

# %%
dc_zips = []
for feat in geojson['features']:
    dc_zips.append(feat["properties"]["ZCTA5CE10"])

# %%
zip_df = pd.read_csv("data/Zip_Zhvi_AllHomes.csv", encoding='latin')
zip_df.rename(columns={"RegionName": "zipcode"}, inplace=True)
zip_df.zipcode = zip_df.zipcode.astype(str)
zip_df.head()
# Out:
#    RegionID zipcode      City State                             Metro  \
# 0     61639   10025  New York    NY       New York-Newark-Jersey City
# 1     84654   60657   Chicago    IL          Chicago-Naperville-Elgin
# 2     61637   10023  New York    NY       New York-Newark-Jersey City
# 3     91982   77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 4     84616   60614   Chicago    IL          Chicago-Naperville-Elgin
#
#         CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2018-10  \
# 0  New York County         1  168300.0  168400.0  168400.0  ...  1072100
# 1      Cook County         2  160000.0  161000.0  161700.0  ...   350700
# 2  New York County         3  353100.0  353700.0  354200.0  ...  1391500
# 3    Harris County         4  210400.0  212200.0  212200.0  ...   336700
# 4      Cook County         5  194400.0  196100.0  197300.0  ...   429900
#
#    2018-11  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# 0  1066500  1054600  1032700  1017300  1011200   991800   974900   970400
# 1   352700   353400   353500   353800   353400   351600   348700   346500
# 2  1383600  1378200  1373300  1373500  1366200  1359900  1370300  1397800
# 3   335900   336000   335600   334200   333400   333500   333500   331800
# 4   431500   432700   433200   433000   431700   429700   427300   424300
#
#    2019-07
# 0   969800
# 1   346100
# 2  1412700
# 3   330100
# 4   422100
#
# [5 rows x 287 columns]

# %%
merged_geo = geo_df.merge(zip_df, on='zipcode', how='inner')
merged_geo
# Out:
#    zipcode                                           geometry  RegionID  \
# 0    20024  (POLYGON ((-77.064251 38.888956, -77.064311 38...     66146
# 1    20004  (POLYGON ((-77.031963 38.897349, -77.031955 38...     66128
# 2    20011  POLYGON ((-77.013606 38.968233, -77.0117730000...     66135
# 3    20018  POLYGON ((-76.963447 38.935202, -76.963382 38....     66141
# 4    20037  POLYGON ((-77.064643 38.891715, -77.064696 38....     66155
# 5    20010  (POLYGON ((-77.055403 38.936371, -77.05646 38....     66134
# 6    20016  POLYGON ((-77.074592 38.957021, -77.0745030000...     66139
# 7    20015  POLYGON ((-77.082977 38.96294, -77.082168 38.9...     66138
# 8    20005  POLYGON ((-77.036542 38.902525, -77.036541 38....     66129
# 9    20017  POLYGON ((-76.98264 38.931967, -76.982563 38.9...     66140
# 10   20003  POLYGON ((-77.00203999999999 38.889808, -77.00...     66127
# 11   20007  POLYGON ((-77.090254 38.927529, -77.089707 38....     66131
# 12   20008  (POLYGON ((-77.053342 38.971939, -77.053354 38...     66132
# 13   20002  POLYGON ((-77.00904199999999 38.916811, -77.00...     66126
# 14   20012  POLYGON ((-77.00700500000001 38.967338, -77.00...     66136
# 15   20009  POLYGON ((-77.048665 38.923351, -77.0487020000...     66133
# 16   20032  (POLYGON ((-77.029764 38.808513, -77.030778 38...     66151
# 17   20020  POLYGON ((-76.99678 38.855056, -76.996844 38.8...     66143
# 18   20036  POLYGON ((-77.0449 38.903742, -77.046646999999...     66154
# 19   20019  POLYGON ((-76.939567 38.916735, -76.939352 38....     66142
# 20   20001  POLYGON ((-77.00904199999999 38.921306, -77.00...     66125
#
#           City State                            Metro            CountyName  \
# 0   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 1   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 2   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 3   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 4   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 5   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 6   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 7   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 8   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 9   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 10  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 11  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 12  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 13  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 14  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 15  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 16  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 17  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 18  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 19  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 20  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
#
#     SizeRank   1996-04   1996-05  ...  2018-10  2018-11  2018-12  2019-01  \
# 0       5019   85300.0   85500.0  ...   405300   407200   409200   411000
# 1      12514       NaN       NaN  ...   463600   465300   466200   465600
# 2        189  113700.0  114200.0  ...   617800   624100   628200   629700
# 3       5350  113500.0  113400.0  ...   535200   536000   535500   531800
# 4       5768  142800.0  142400.0  ...   529400   529900   531400   532500
# 5       2599  102400.0  103000.0  ...   714700   716500   715000   710800
# 6       2077  267600.0  268800.0  ...   974000   979800   982500   984400
# 7       6471  296000.0  296200.0  ...  1019900  1028700  1036200  1042700
# 8       5274       NaN       NaN  ...   503000   503000   503100   502700
# 9       5474  113900.0  114200.0  ...   543900   545300   547800   548300
# 10      1249  114900.0  115100.0  ...   779900   786000   792700   797200
# 11      2712  258500.0  258500.0  ...  1012200  1017200  1022200  1022600
# 12      1281  234500.0  234500.0  ...   880600   884400   886200   889200
# 13        32   91500.0   91700.0  ...   669700   675700   680000   679800
# 14      7034  171500.0  172400.0  ...   738900   742900   747000   748700
# 15        41  116700.0  117100.0  ...   552900   554600   557300   558500
# 16      1672       NaN       NaN  ...   305700   311800   318300   322400
# 17       424   94000.0   94100.0  ...   331200   338400   346500   351300
# 18      9115   82600.0   82600.0  ...   372600   373200   374000   373700
# 19       283   87400.0   87700.0  ...   320800   324800   328000   331100
# 20       255       NaN       NaN  ...   668600   670500   673400   675000
#
#     2019-02  2019-03  2019-04  2019-05  2019-06  2019-07
# 0    413300   414700   414100   411900   411200   411200
# 1    463900   464000   466000   466500   466200   466700
# 2    628300   621500   607200   593100   587200   586100
# 3    528800   526000   518400   509100   502900   499300
# 4    525000   512700   504700   503600   504500   506200
# 5    707700   706900   703000   697400   696800   699500
# 6    986300   985900   980400   972900   969600   969300
# 7   1049000  1058300  1068900  1067000  1050700  1036500
# 8    502200   502100   501200   498900   498300   499000
# 9    545100   535800   522200   511700   509000   508300
# 10   798600   796200   788100   777600   772500   771800
# 11  1016900  1006700   992600   978900   971600   969600
# 12   893600   895800   889500   880800   879500   884100
# 13   677700   670200   653900   637400   632300   633000
# 14   746100   734400   710800   689800   681000   678000
# 15   558400   559200   559700   559500   560100   560800
# 16   326300   325700   318200   310200   308200   308100
# 17   354000   352900   345700   340800   343400   346300
# 18   372600   372400   372400   372200   372100   371700
# 19   335200   335400   331000   326400   324800   324500
# 20   675200   673400   664400   653500   650900   653200
#
# [21 rows x 288 columns]

# %%
def format_dates(df):
    """
    takes the merged geo_df and return a new df with average median price per year in each zipcode
    """
    
    zipcodes = df.zipcode
    columns = df.columns
    collection = []
    for z in zipcodes:
        current_df = df[df.zipcode == z]
        for year in range(1996, 2020):
            year = str(year)
            date_cols = [x for x in columns if year in x]
            
            year_average = round(np.mean(current_df[date_cols].T.iloc[:,0]), 2)
            collection.append({"zipcode": z, year: year_average})
    return df.merge(gpd.GeoDataFrame(collection).groupby('zipcode').mean(), on='zipcode', how='left')

final_geo_df = format_dates(merged_geo)

# %%
final_geo_df
# Out:
#    zipcode                                           geometry  RegionID  \
# 0    20024  (POLYGON ((-77.064251 38.888956, -77.064311 38...     66146
# 1    20004  (POLYGON ((-77.031963 38.897349, -77.031955 38...     66128
# 2    20011  POLYGON ((-77.013606 38.968233, -77.0117730000...     66135
# 3    20018  POLYGON ((-76.963447 38.935202, -76.963382 38....     66141
# 4    20037  POLYGON ((-77.064643 38.891715, -77.064696 38....     66155
# 5    20010  (POLYGON ((-77.055403 38.936371, -77.05646 38....     66134
# 6    20016  POLYGON ((-77.074592 38.957021, -77.0745030000...     66139
# 7    20015  POLYGON ((-77.082977 38.96294, -77.082168 38.9...     66138
# 8    20005  POLYGON ((-77.036542 38.902525, -77.036541 38....     66129
# 9    20017  POLYGON ((-76.98264 38.931967, -76.982563 38.9...     66140
# 10   20003  POLYGON ((-77.00203999999999 38.889808, -77.00...     66127
# 11   20007  POLYGON ((-77.090254 38.927529, -77.089707 38....     66131
# 12   20008  (POLYGON ((-77.053342 38.971939, -77.053354 38...     66132
# 13   20002  POLYGON ((-77.00904199999999 38.916811, -77.00...     66126
# 14   20012  POLYGON ((-77.00700500000001 38.967338, -77.00...     66136
# 15   20009  POLYGON ((-77.048665 38.923351, -77.0487020000...     66133
# 16   20032  (POLYGON ((-77.029764 38.808513, -77.030778 38...     66151
# 17   20020  POLYGON ((-76.99678 38.855056, -76.996844 38.8...     66143
# 18   20036  POLYGON ((-77.0449 38.903742, -77.046646999999...     66154
# 19   20019  POLYGON ((-76.939567 38.916735, -76.939352 38....     66142
# 20   20001  POLYGON ((-77.00904199999999 38.921306, -77.00...     66125
#
#           City State                            Metro            CountyName  \
# 0   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 1   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 2   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 3   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 4   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 5   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 6   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 7   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 8   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 9   Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 10  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 11  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 12  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 13  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 14  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 15  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 16  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 17  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 18  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
# 19  Washington    DC  Washington-Arlington-Alexandria  District of Columbia
        date = str(date)
        
        colormap = folium.LinearColormap(colors=['#FFFFCC', '#D9F0A3', '#ADDD8E',
                                '#78C679', '#41AB5D', '#238443', '#005A32'], vmin=0.0, vmax=1_000_000, )

        def style_function(x):
            return {
                'weight': 0.5,
                'color': 'black',
                'fillColor': colormap(x['properties'][date]),
                'fillOpacity': 0.3
            }

        def highlight_function(x):
            return {
                'weight': 2,
                'color': 'red'
            }

        tooltip = folium.features.GeoJsonTooltip(
            fields=['zipcode', date],
            aliases=['Zipcode', f'{date} Median Home Price'],
            labels=True,
            sticky=True,
            localize=True
        )

        m = folium.Map(location=[ 38.9072, -77.0369], zoom_start=11, tiles="cartodbpositron")

        folium.GeoJson(
            data=final_geo_df[["zipcode", 'geometry', date]].dropna(),
            name="DC Zipcodes",
            style_function=style_function,
            highlight_function= highlight_function,
            smooth_factor=1.0,
            tooltip=tooltip
        ).add_to(m)

        colormap.add_to(m)
        folium.LayerControl().add_to(m)
        
        if save:
            m.save(f"map-{date}.html")
        else:
            return m

# %%
make_maps((1996, 2019))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dc_data = zip_df[zip_df.RegionName.isin(dc_zips)]
dc_data.rename(columns={"RegionName": "zipcode"}, inplace=True)
dc_data.iloc[:, 1] = dc_data['zipcode'].astype(str)

dc_data.drop(["RegionID", "City", "State", "Metro", "CountyName", "SizeRank"], axis=1, inplace=True)

# dc_data.set_index("zipcode", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-347-24107762407a> in <module>
# ----> 1 dc_data = zip_df[zip_df.RegionName.isin(dc_zips)]
#       2 dc_data.rename(columns={"RegionName": "zipcode"}, inplace=True)
#       3 dc_data.iloc[:, 1] = dc_data['zipcode'].astype(str)
#       4
#       5 dc_data.drop(["RegionID", "City", "State", "Metro", "CountyName", "SizeRank"], axis=1, inplace=True)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'RegionName'

# %%
formatted_data = []

for col in dc_data.columns[1:]:
    for z in dc_data.zipcode:        
        at_zip = dc_data[col][dc_data.zipcode == z]
        value = at_zip[at_zip.index[0]]
        
        formatted_data.append({'date': col, 'zipcode': z, "price": value})
        
dc_reformat_data = pd.DataFrame(formatted_data)

# %%
dc_reformat_data.date = pd.to_datetime(dc_reformat_data.date)
dc_reformat_data.set_index("date", inplace=True)

# %%
dc_no_date = dc_reformat_data.groupby('zipcode').mean()
dc_data = dc_no_date.reset_index()
dc_data.head()
# Out:
#   zipcode          price
# 0   20001  481578.756477
# 1   20002  331710.357143
# 2   20003  447822.142857
# 3   20004  416552.849741
# 4   20005  428826.943005

# %%
m = folium.Map(location=[ 38.9072, -77.0369], zoom_start=11, tiles="cartodbpositron")

dc_json = "https://raw.githubusercontent.com/OpenDataDE/State-zip-code-GeoJSON/master/dc_district_of_columbia_zip_codes_geo.min.json"

# folium.Choropleth(
#     geo_data=dc_json,
#     name="DC",
#     data=dc_data,
#     columns=["zipcode", "price"],
#     key_on="feature.properties.ZCTA5CE10",
#     fill_color="YlGn",
#     nan_fill_color="black",
#     nan_fill_opacity=0.2,
#     fill_opacity=0.5,
#     line_opacity=0.4,
#     legend_name='Average Home Price',
# ).add_to(m)

folium.features.GeoJson(
    
)

folium.LayerControl().add_to(m)

m

# m.save('index.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
